# %%
#Name: Rudranarayan Jena.  PRN: 20250802081
import itertools
A={1,2}
B={'a','b','c'}
cartesian_product= list(itertools.product(A,B))
print("Ordered pairs of (A x B):")
print(cartesian_product)
cardinality= len(cartesian_product)
print(f"\nCardinality: {cardinality}")
# Out:
# Ordered pairs of (A x B):
# [(1, 'b'), (1, 'c'), (1, 'a'), (2, 'b'), (2, 'c'), (2, 'a')]
#
# Cardinality: 6

# %%
#Name: Rudranarayan Jena.  PRN: 20250802081
A={1,2,3,4,5,}
B={2,4,6,7}
cartesian_product = set()
for a in A:
    for b in B:
        cartesian_product.add((a,b))
print(cartesian_product)
# Out:
# {(3, 4), (3, 7), (5, 4), (4, 6), (5, 7), (2, 2), (1, 6), (4, 2), (5, 6), (3, 6), (2, 4), (1, 2), (2, 7), (3, 2), (4, 7), (5, 2), (4, 4), (1, 4), (1, 7), (2, 6)}

# %%
#Name: Rudranarayan Jena.  PRN: 20250802081
A={11,2,3,4,5,63}
B={'x','y','z','w'}
cartesian_product=set()
for a in A:
    for b in B:
        cartesian_product.add((a,b))
print(cartesian_product)
cardinality= len(A)* len(B)
print(cardinality)
# Out:
# {(2, 'y'), (11, 'z'), (2, 'x'), (2, 'z'), (11, 'x'), (4, 'y'), (11, 'w'), (2, 'w'), (4, 'z'), (4, 'x'), (63, 'y'), (4, 'w'), (3, 'y'), (63, 'x'), (63, 'z'), (5, 'y'), (3, 'x'), (3, 'z'), (5, 'x'), (5, 'z'), (63, 'w'), (3, 'w'), (5, 'w'), (11, 'y')}
# 24
